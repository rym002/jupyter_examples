# %% [markdown]
# # Scaling Numerical Data
# ## Demo

# %%
import pandas as pd

# %%
print(pd.__version__)
# Out:
# 1.2.1

# %% [markdown]
# ### Load Data

# %%
exam_data = pd.read_csv("http://roycekimmons.com/system/generate_data.php?dataset=exams&n=100",quotechar="\"")
exam_data
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 0     male        group E           bachelor's degree      standard
# 1     male        group C          associate's degree  free/reduced
# 2     male        group D                some college  free/reduced
# 3   female        group C          associate's degree      standard
# 4   female        group A          associate's degree      standard
# ..     ...            ...                         ...           ...
# 95    male        group E                 high school      standard
# 96  female        group D             master's degree  free/reduced
# 97  female        group D            some high school      standard
# 98  female        group B                 high school      standard
# 99    male        group B                some college      standard
#
#    test preparation course  math score  reading score  writing score
# 0                completed          49             52             52
# 1                     none          31             42             28
# 2                completed          76             70             69
# 3                completed          90             99             94
# 4                     none          87             88             95
# ..                     ...         ...            ...            ...
# 95               completed          61             61             56
# 96                    none          75             78             75
# 97                    none          53             62             69
# 98               completed          75             84             88
# 99                    none          68             60             59
#
# [100 rows x 8 columns]

# %% [markdown]
# ### Show current average

# %%
math_average = exam_data['math score'].mean()
reading_average = exam_data['reading score'].mean()
writing_average = average = exam_data['writing score'].mean()

print('Math Avg: ', math_average)
print('Reading Avg: ', reading_average)
print('Writing Avg: ', writing_average)
# Out:
# Math Avg:  66.32
# Reading Avg:  68.2
# Writing Avg:  67.75

# %% [markdown]
# ### Scale data

# %%
from sklearn import preprocessing

exam_data[['math score']]=preprocessing.scale(exam_data[['math score']])
exam_data[['reading score']]=preprocessing.scale(exam_data[['reading score']])
exam_data[['writing score']]=preprocessing.scale(exam_data[['writing score']])

# %%
exam_data
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 0     male        group E           bachelor's degree      standard
# 1     male        group C          associate's degree  free/reduced
# 2     male        group D                some college  free/reduced
# 3   female        group C          associate's degree      standard
# 4   female        group A          associate's degree      standard
# ..     ...            ...                         ...           ...
# 95    male        group E                 high school      standard
# 96  female        group D             master's degree  free/reduced
# 97  female        group D            some high school      standard
# 98  female        group B                 high school      standard
# 99    male        group B                some college      standard
#
#    test preparation course  math score  reading score  writing score
# 0                completed   -1.167349      -1.065375      -0.976722
# 1                     none   -2.380530      -1.723013      -2.465060
# 2                completed    0.652421       0.118375       0.077518
# 3                completed    1.596006       2.025527       1.627870
# 4                     none    1.393810       1.302124       1.689884
# ..                     ...         ...            ...            ...
# 95               completed   -0.358562      -0.473500      -0.728666
# 96                    none    0.585023       0.644486       0.449602
# 97                    none   -0.897754      -0.407736       0.077518
# 98               completed    0.585023       1.039069       1.255785
# 99                    none    0.113230      -0.539264      -0.542623
#
# [100 rows x 8 columns]

# %%
math_average = exam_data['math score'].mean()
reading_average = exam_data['reading score'].mean()
writing_average = average = exam_data['writing score'].mean()

print('Math Avg: ', math_average)
print('Reading Avg: ', reading_average)
print('Writing Avg: ', writing_average)
# Out:
# Math Avg:  4.804490139065365e-16
# Reading Avg:  -2.2759572004815707e-16
# Writing Avg:  -2.220446049250313e-18

# %% [markdown]
# # Label gender

# %%
le = preprocessing.LabelEncoder()
exam_data['gender']=le.fit_transform(exam_data['gender'].astype(str))

# %%
exam_data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0       1        group E           bachelor's degree      standard
# 1       1        group C          associate's degree  free/reduced
# 2       1        group D                some college  free/reduced
# 3       0        group C          associate's degree      standard
# 4       0        group A          associate's degree      standard
#
#   test preparation course  math score  reading score  writing score
# 0               completed   -1.167349      -1.065375      -0.976722
# 1                    none   -2.380530      -1.723013      -2.465060
# 2               completed    0.652421       0.118375       0.077518
# 3               completed    1.596006       2.025527       1.627870
# 4                    none    1.393810       1.302124       1.689884

# %% [markdown]
# ### Display mapping

# %%
le.classes_
# Out:
# array(['female', 'male'], dtype=object)

# %% [markdown]
# ### One hot representation

# %%
pd.get_dummies(exam_data['race/ethnicity'])
# Out:
#     group A  group B  group C  group D  group E
# 0         0        0        0        0        1
# 1         0        0        1        0        0
# 2         0        0        0        1        0
# 3         0        0        1        0        0
# 4         1        0        0        0        0
# ..      ...      ...      ...      ...      ...
# 95        0        0        0        0        1
# 96        0        0        0        1        0
# 97        0        0        0        1        0
# 98        0        1        0        0        0
# 99        0        1        0        0        0
#
# [100 rows x 5 columns]

# %% [markdown]
# #### Assign race one hot to table

# %%
exam_data = pd.get_dummies(exam_data,columns=['race/ethnicity'])

# %%
exam_data
# Out:
#     gender parental level of education         lunch test preparation course  \
# 0        1           bachelor's degree      standard               completed
# 1        1          associate's degree  free/reduced                    none
# 2        1                some college  free/reduced               completed
# 3        0          associate's degree      standard               completed
# 4        0          associate's degree      standard                    none
# ..     ...                         ...           ...                     ...
# 95       1                 high school      standard               completed
# 96       0             master's degree  free/reduced                    none
# 97       0            some high school      standard                    none
# 98       0                 high school      standard               completed
# 99       1                some college      standard                    none
#
#     math score  reading score  writing score  race/ethnicity_group A  \
# 0    -1.167349      -1.065375      -0.976722                       0
# 1    -2.380530      -1.723013      -2.465060                       0
# 2     0.652421       0.118375       0.077518                       0
# 3     1.596006       2.025527       1.627870                       0
# 4     1.393810       1.302124       1.689884                       1
# ..         ...            ...            ...                     ...
# 95   -0.358562      -0.473500      -0.728666                       0
# 96    0.585023       0.644486       0.449602                       0
# 97   -0.897754      -0.407736       0.077518                       0
# 98    0.585023       1.039069       1.255785                       0
# 99    0.113230      -0.539264      -0.542623                       0
#
#     race/ethnicity_group B  race/ethnicity_group C  race/ethnicity_group D  \
# 0                        0                       0                       0
# 1                        0                       1                       0
# 2                        0                       0                       1
# 3                        0                       1                       0
# 4                        0                       0                       0
# ..                     ...                     ...                     ...
# 95                       0                       0                       0
# 96                       0                       0                       1
# 97                       0                       0                       1
# 98                       1                       0                       0
# 99                       1                       0                       0
#
#     race/ethnicity_group E
# 0                        1
# 1                        0
# 2                        0
# 3                        0
# 4                        0
# ..                     ...
# 95                       1
# 96                       0
# 97                       0
# 98                       0
# 99                       0
#
# [100 rows x 12 columns]

# %% [markdown]
# #### Multicolumn One Hot Notation

# %%
exam_data = pd.get_dummies(exam_data,columns=['parental level of education',
                                             'lunch',
                                             'test preparation course'])

# %%
exam_data.head()
# Out:
#    gender  math score  reading score  writing score  race/ethnicity_group A  \
# 0       1   -1.167349      -1.065375      -0.976722                       0
# 1       1   -2.380530      -1.723013      -2.465060                       0
# 2       1    0.652421       0.118375       0.077518                       0
# 3       0    1.596006       2.025527       1.627870                       0
# 4       0    1.393810       1.302124       1.689884                       1
#
#    race/ethnicity_group B  race/ethnicity_group C  race/ethnicity_group D  \
# 0                       0                       0                       0
# 1                       0                       1                       0
# 2                       0                       0                       1
# 3                       0                       1                       0
# 4                       0                       0                       0
#
#    race/ethnicity_group E  parental level of education_associate's degree  \
# 0                       1                                               0
# 1                       0                                               1
# 2                       0                                               0
# 3                       0                                               1
# 4                       0                                               1
#
#    parental level of education_bachelor's degree  \
# 0                                              1
# 1                                              0
# 2                                              0
# 3                                              0
# 4                                              0
#
#    parental level of education_high school  \
# 0                                        0
# 1                                        0
# 2                                        0
# 3                                        0
# 4                                        0
#
#    parental level of education_master's degree  \
# 0                                            0
# 1                                            0
# 2                                            0
# 3                                            0
# 4                                            0
#
#    parental level of education_some college  \
# 0                                         0
# 1                                         0
# 2                                         1
# 3                                         0
# 4                                         0
#
#    parental level of education_some high school  lunch_free/reduced  \
# 0                                             0                   0
# 1                                             0                   1
# 2                                             0                   1
# 3                                             0                   0
# 4                                             0                   0
#
#    lunch_standard  test preparation course_completed  \
# 0               1                                  1
# 1               0                                  0
# 2               0                                  1
# 3               1                                  1
# 4               1                                  0
#
#    test preparation course_none
# 0                             0
# 1                             1
# 2                             0
# 3                             0
# 4                             1
